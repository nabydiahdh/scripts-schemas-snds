# %%
table=['CT_IND_AAAA_GN', 'CT_DEP_AAAA_GN', 'CT_IDE_AAAA_GN']
lib=["Table pathologies de la cartographie des pathologies pour l'année AAAA et l'algorithme N","Table dépenses de la cartographie des pathologies pour l'année AAAA et l'algorithme N","Table individus de la cartographie des pathologies pour l'année AAAA et l'algorithme N"]
tableexist={
    'tables':table,
    'tab_lib':lib,
    'produit':"CAROGRAPHIE_PATHOLOGIES"
}

# %%
pip install tableschema
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tableschema
#   Downloading tableschema-1.20.2-py2.py3-none-any.whl (68 kB)
#      |████████████████████████████████| 68 kB 3.2 MB/s
# Requirement already satisfied: requests>=2.5 in /usr/local/lib/python3.7/dist-packages (from tableschema) (2.23.0)
# Requirement already satisfied: click>=3.3 in /usr/local/lib/python3.7/dist-packages (from tableschema) (7.1.2)
# Requirement already satisfied: jsonschema>=2.5 in /usr/local/lib/python3.7/dist-packages (from tableschema) (4.3.3)
# Collecting tabulator>=1.51.3
#   Downloading tabulator-1.53.5-py2.py3-none-any.whl (72 kB)
#      |████████████████████████████████| 72 kB 448 kB/s
# Collecting rfc3986>=1.1.0
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Collecting isodate>=0.5.4
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 496 kB/s
# Requirement already satisfied: cached-property>=1.5 in /usr/local/lib/python3.7/dist-packages (from tableschema) (1.5.2)
# Collecting unicodecsv>=0.14
#   Downloading unicodecsv-0.14.1.tar.gz (10 kB)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.7/dist-packages (from tableschema) (2.8.2)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from tableschema) (1.15.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.5->tableschema) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.5->tableschema) (0.18.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.5->tableschema) (4.13.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.5->tableschema) (4.1.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.5->tableschema) (5.10.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.5->tableschema) (3.9.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5->tableschema) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5->tableschema) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5->tableschema) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5->tableschema) (1.24.3)
# Collecting boto3>=1.9
#   Downloading boto3-1.24.94-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 36.3 MB/s
# Collecting jsonlines>=1.1
#   Downloading jsonlines-3.1.0-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: sqlalchemy>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from tabulator>=1.51.3->tableschema) (1.4.41)
# Collecting linear-tsv>=1.0
#   Downloading linear-tsv-1.1.0.tar.gz (9.6 kB)
# Requirement already satisfied: openpyxl>=2.6 in /usr/local/lib/python3.7/dist-packages (from tabulator>=1.51.3->tableschema) (3.0.10)
# Requirement already satisfied: xlrd>=1.0 in /usr/local/lib/python3.7/dist-packages (from tabulator>=1.51.3->tableschema) (1.1.0)
# Collecting ijson>=3.0.3
#   Downloading ijson-3.1.4-cp37-cp37m-manylinux2010_x86_64.whl (126 kB)
#      |████████████████████████████████| 126 kB 56.9 MB/s
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 6.8 MB/s
# Collecting botocore<1.28.0,>=1.27.94
#   Downloading botocore-1.27.94-py3-none-any.whl (9.3 MB)
#      |████████████████████████████████| 9.3 MB 64.8 MB/s
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 61.1 MB/s
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl>=2.6->tabulator>=1.51.3->tableschema) (1.1.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=0.9.6->tabulator>=1.51.3->tableschema) (1.1.3.post0)
# Building wheels for collected packages: linear-tsv, unicodecsv
#   Building wheel for linear-tsv (setup.py) ... done
#   Created wheel for linear-tsv: filename=linear_tsv-1.1.0-py3-none-any.whl size=7400 sha256=9f220358d8ef9332e5a05a3f59cc1de28abe841d56fbe7feeb4e1a265943f728
#   Stored in directory: /root/.cache/pip/wheels/dd/0a/62/49ee84fab92057fb3e303fb1a59e75ccac6899b417f441305a
#   Building wheel for unicodecsv (setup.py) ... done
#   Created wheel for unicodecsv: filename=unicodecsv-0.14.1-py3-none-any.whl size=10768 sha256=011700bdce04d7ec04ff14007e623924f8fc1256ce52c27409ad51a1b1070fe0
#   Stored in directory: /root/.cache/pip/wheels/1a/f4/8a/a5024fb77b32ed369e5c409081e5f00fbe3b92fdad653f6e69
# Successfully built linear-tsv unicodecsv
# Installing collected packages: urllib3, jmespath, botocore, s3transfer, unicodecsv, linear-tsv, jsonlines, ijson, boto3, tabulator, rfc3986, isodate, tableschema
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed boto3-1.24.94 botocore-1.27.94 ijson-3.1.4 isodate-0.6.1 jmespath-1.0.1 jsonlines-3.1.0 linear-tsv-1.1.0 rfc3986-2.0.0 s3transfer-0.6.0 tableschema-1.20.2 tabulator-1.53.5 unicodecsv-0.14.1 urllib3-1.25.11

# %%
df
# Out:
#             variables                                                lib  \
# 0                 AGE                                Age du bénéficiaire
# 1         ASS_AAH_TOP      Bénéficiaire de l'allocation adulte handicapé
# 2         BEN_ACS_TOP   Bénéficiaire de l'aide à la complémentaire santé
# 3         BEN_ALD_TOP  Bénéficiaire d'une exonération du ticket modér...
# 4         BEN_DCD_AME             Année et mois de décès du bénéficiaire
# ..                ...                                                ...
# 180   TOP_PTRENFA_IND  Troubles psychiatriques ayant débuté dans l'en...
# 181  TOP_RDIALYSE_IND                                  Dialyse chronique
# 182    TOP_RTRANS_AIG                             Transplantation rénale
# 183    TOP_RTRANS_CHR                    Suivi de transplantation rénale
# 184           VERSION                                            Version
#
#      Type  length 2012 2013 2014 2015 2016 2017 2018 2019     type  \
# 0     Num       8    X    X    X    X    X    X    X    X  integer
# 1     Num       3    X    X    X    X    X    X    X    X  integer
# 2     Num       3    X    X    X    X    X    X    X    X  integer
# 3     Num       3    X    X    X    X    X    X    X    X  integer
# 4    Char       6    X    X    X                            string
# ..    ...     ...  ...  ...  ...  ...  ...  ...  ...  ...      ...
# 180   Num       3    X    X    X    X    X    X    X    X  integer
# 181   Num       3    X    X    X    X    X    X    X    X  integer
# 182   Num       3    X    X    X    X    X    X    X    X  integer
# 183   Num       3    X    X    X    X    X    X    X    X  integer
# 184  Char       2                   X    X    X    X    X   string
#
#     datecreated datedeleted datemissing observation rdg           table
# 0                                                        CT_IND_AAAA_GN
# 1                                                        CT_IND_AAAA_GN
# 2                                                        CT_IND_AAAA_GN
# 3                                                        CT_IND_AAAA_GN
# 4                                                        CT_IND_AAAA_GN
# ..          ...         ...         ...         ...  ..             ...
# 180                                                      CT_IND_AAAA_GN
# 181                                                      CT_IND_AAAA_GN
# 182                                                      CT_IND_AAAA_GN
# 183                                                      CT_IND_AAAA_GN
# 184                                                      CT_IND_AAAA_GN
#
# [185 rows x 19 columns]

# %%
annees=range(2012, 2020)

# %%
annees
# Out:
# range(2012, 2020)

# %%
from tableschema import Schema
import json
for table in tableexist['tables']:
  with open('{}.json'.format(table),'w', encoding='utf-8') as f:
    json.dump([],f, indent=4,ensure_ascii=False)
  import pandas as pd 
  df= pd.read_csv("{}.csv".format(table), sep=",",encoding='utf-8',na_values="")
  df.rename(columns={'Nom Variable':'variables','Libellé':'lib','Taille':'length'}, inplace=True)
  df=df.fillna('')


  ##### transformation des types 
  mapping_t = {
    "Char": "string",
    "Num":"integer",
    "Date":"date"
  }
  df["type"]=df["Type"].map(mapping_t)
  # Fonction qui permet de classer le type en number ou integer en fct de la taille 
  def numbint(x): 
    res = re.search(",", x)
    if res:
      return "number"
    return "integer"
  df["datecreated"]=''
  df["datedeleted"]=''
  df["datemissing"]=''
  df['observation']=''
  df['nomenclature']=''
  df["rdg"]=''
  df['table']=table
  
 # date of variable creation 
  annees=range(2012, 2020)
  for y in range(len(df['variables'])):
    for annee in annees:
      if df['{}'.format(annee)][y]=='X':
        df['datecreated'][y]=annee
        abs=range(annee,2020)
        for ab in abs:
          if df['{}'.format(ab)][y]=='':
            df['datedeleted'][y]=ab
            break
        break

 # Creation dy type oracle 
  mapping_to = {
    "string": "string",
    "date":"date",
    "integer":"number"
    
    }

  df["type_oracle"]=df["type"].map(mapping_to)

 
# Creation des fichiers json 
  for i in range(len(df['variables'])):
    if df['type'][i]=='number':
      df['type'][i]=df['length'][i].apply(numbint)    
     # les colonnes manquante  
  df=df.fillna('')
  
# create json file with the tables name

  for z in range(len(df['variables'])): 
    new_dict={
            "name": df["variables"][z],
            "description": df["lib"][z],
            "type": df["type"][z],
            "nomenclature": df["nomenclature"][z],
            "length": str(df["length"][z]),
            "format": "default",
            "dateCreated": str(df["datecreated"][z]),
            "dateDeleted": str(df["datedeleted"][z]),
            "dateMissing": df["datemissing"][z],
            "observation": df["observation"][z],
            "regle_gestion": df["rdg"][z],
            "type_oracle": df["type_oracle"][z]
       
        }
    
    with open('{}.json'.format(table),encoding='utf-8') as f:  
      data=json.load(f)
      data.append(new_dict)
    with open('{}.json'.format(table), 'w', encoding='utf-8') as f:
      json.dump(data, f, indent=4, ensure_ascii=False)
  # Mettons les fichiers sous format tableschema

from tableschema import Schema
for table in tableexist['tables']:
  with open('{}.json'.format(table), "r", encoding='utf-8') as f:
    descriptor = {'fields': json.load(f)}
    schema=Schema(descriptor) 
    schema.descriptor['name']=table
    schema.descriptor['title']=tableexist['tab_lib'][tableexist['tables'].index(table)]
    schema.descriptor['produit']=tableexist['produit']
    schema.descriptor['missingValues'] = ['']
    if table=='CT_IDE_AAAA_GN':
      schema.descriptor['primaryKey']= [
        "BEN_NIR_PSA",
        "BEN_RNG_GEM"
    ]
      schema.descriptor['foreignKeys'] = [
        {
            "fields": [
                "BEN_NIR_PSA",
                "BEN_RNG_GEM"
            ],
            "reference": {
                "resource": "IR_BEN_R",
                "fields": [
                    "BEN_NIR_PSA",
                    "BEN_RNG_GEM"
                ]
            },
            "description": "Bidirectionnel"
        }
    ]

    
                               
    schema.descriptor['foreignKeys'] =[
        {
            "fields": "id_carto",
            "reference": {
                "resource": "CT_IDE_AAAA_GN",
                "fields": "id_carto"
            }
        }
    ]

    schema.descriptor['history']={"dateCreated": str(schema.descriptor['fields'][0]['dateCreated']),
                                    "dateDeleted": "",
                                    "dateMissing": []}
    schema.descriptor['champ']=''
    schema.descriptor['observation']=''

    schema.commit()
    schema.save('{}.json'.format(table),ensure_ascii=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
